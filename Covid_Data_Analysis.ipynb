# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvsgthn/Classification/blob/main/Covid_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd drive/MyDrive/Crayon
# Out:
# /content/drive/MyDrive/Crayon

# %%
#ziping the data
# !zip -r "./dataset.zip" "./temp/"
# Out:
# updating: temp/ (stored 0%)
# updating: temp/Train/ (stored 0%)
# updating: temp/Train/covid_p/ (stored 0%)
# updating: temp/Train/covid_n/ (stored 0%)
# updating: temp/Test/ (stored 0%)
# updating: temp/Test/covid_p/ (stored 0%)
# updating: temp/Test/covid_n/ (stored 0%)
# updating: temp/Validation/ (stored 0%)
# updating: temp/Validation/covid_p/ (stored 0%)
# updating: temp/Validation/covid_n/ (stored 0%)
#   adding: temp/covid_n/ (stored 0%)
#   adding: temp/covid_p/ (stored 0%)
#   adding: temp/Test/covid_p/img (104).jpg (deflated 1%)
#   adding: temp/Test/covid_p/img (107).jpg (deflated 10%)
#   adding: temp/Test/covid_p/img (11).jpg (deflated 3%)
#   adding: temp/Test/covid_p/img (118).jpg (deflated 4%)
#   adding: temp/Test/covid_p/img (119).jpg (deflated 4%)
#   adding: temp/Test/covid_p/img (13).png (deflated 1%)
#   adding: temp/Test/covid_p/img (15).jpg (deflated 1%)
#   adding: temp/Test/covid_p/img (16).png (deflated 1%)
#   adding: temp/Test/covid_p/img (18).jpg (deflated 5%)
#   adding: temp/Test/covid_p/img (2).jpg (deflated 3%)
#   adding: temp/Test/covid_p/img (20).png (deflated 1%)
#   adding: temp/Test/covid_p/img (22).jpg (deflated 4%)
#   adding: temp/Test/covid_p/img (23).png (deflated 2%)
#   adding: temp/Test/covid_p/img (26).jpg (deflated 2%)
#   adding: temp/Test/covid_p/img (27).png (deflated 1%)
#   adding: temp/Test/covid_p/img (3).png (deflated 0%)
#   adding: temp/Test/covid_p/img (32).jpg (deflated 2%)
#   adding: temp/Test/covid_p/img (38).JPG (deflated 11%)
#   adding: temp/Test/covid_p/img (48).jpg (deflated 1%)
#   adding: temp/Test/covid_p/img (5).png (deflated 2%)
#   adding: temp/Test/covid_p/img (51).jpg (deflated 0%)
#   adding: temp/Test/covid_p/img (58).jpg (deflated 1%)
#   adding: temp/Test/covid_p/img (6).jpg (deflated 0%)
#   adding: temp/Test/covid_p/img (65).jpg (deflated 1%)
#   adding: temp/Test/covid_p/img (70).jpg (deflated 3%)
#   adding: temp/Test/covid_p/img (77).jpg (deflated 3%)
#   adding: temp/Test/covid_p/img (82).jpg (deflated 3%)
#   adding: temp/Test/covid_p/img (86).jpg (deflated 4%)
#   adding: temp/Test/covid_p/img (9).png (deflated 0%)
#   adding: temp/Test/covid_p/img (91).jpg (deflated 1%)
#   adding: temp/Test/covid_n/img (27).jpeg (deflated 3%)
#   adding: temp/Test/covid_n/img (37).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (4).jpeg (deflated 0%)
#   adding: temp/Test/covid_n/img (40).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (43).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (48).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (49).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (5).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (56).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (57).jpeg (deflated 3%)
#   adding: temp/Test/covid_n/img (6).png (deflated 0%)
#   adding: temp/Test/covid_n/img (61).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (64).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (69).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (7).jpeg (deflated 0%)
#   adding: temp/Test/covid_n/img (71).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (72).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (77).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (78).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (8).jpg (deflated 2%)
#   adding: temp/Test/covid_n/img (81).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (84).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (91).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (94).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (99).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (10).jpg (deflated 1%)
#   adding: temp/Test/covid_n/img (102).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (107).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (11).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (110).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (115).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (118).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (123).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (126).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (13).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (13).jpg (deflated 2%)
#   adding: temp/Test/covid_n/img (131).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (132).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (135).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (139).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (140).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (145).jpeg (deflated 2%)
#   adding: temp/Test/covid_n/img (146).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (15).jpg (deflated 3%)
#   adding: temp/Test/covid_n/img (151).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (152).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (16).jpeg (deflated 0%)
#   adding: temp/Test/covid_n/img (18).jpg (deflated 1%)
#   adding: temp/Test/covid_n/img (19).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (2).jpeg (deflated 0%)
#   adding: temp/Test/covid_n/img (2).jpg (deflated 2%)
#   adding: temp/Test/covid_n/img (21).jpg (deflated 1%)
#   adding: temp/Test/covid_n/img (23).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (24).jpg (deflated 0%)
#   adding: temp/Test/covid_n/img (26).jpg (deflated 2%)
#   adding: temp/Test/covid_n/img (28).jpg (deflated 2%)
#   adding: temp/Test/covid_n/img (3).jpg (deflated 2%)
#   adding: temp/Test/covid_n/img (30).jpeg (deflated 1%)
#   adding: temp/Test/covid_n/img (32).jpg (deflated 4%)
#   adding: temp/Test/covid_n/img (34).jpeg (deflated 1%)
#   adding: temp/Validation/covid_p/img (11).png (deflated 1%)
#   adding: temp/Validation/covid_p/img (14).png (deflated 1%)
#   adding: temp/Validation/covid_p/img (18).png (deflated 1%)
#   adding: temp/Validation/covid_p/img (22).png (deflated 1%)
#   adding: temp/Validation/covid_p/img (27).jpg (deflated 1%)
#   adding: temp/Validation/covid_p/img (36).jpg (deflated 0%)
#   adding: temp/Validation/covid_p/img (40).jpg (deflated 2%)
#   adding: temp/Validation/covid_p/img (47).jpg (deflated 1%)
#   adding: temp/Validation/covid_p/img (54).jpg (deflated 3%)
#   adding: temp/Validation/covid_p/img (64).jpg (deflated 0%)
#   adding: temp/Validation/covid_p/img (68).jpg (deflated 4%)
#   adding: temp/Validation/covid_p/img (7).jpg (deflated 2%)
#   adding: temp/Validation/covid_p/img (76).jpg (deflated 1%)
#   adding: temp/Validation/covid_p/img (93).jpg (deflated 3%)
#   adding: temp/Validation/covid_p/img (98).jpg (deflated 5%)
#   adding: temp/Validation/covid_n/img (38).jpeg (deflated 2%)
#   adding: temp/Validation/covid_n/img (4).png (deflated 3%)
#   adding: temp/Validation/covid_n/img (45).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (50).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (9).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (96).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (103).jpeg (deflated 3%)
#   adding: temp/Validation/covid_n/img (112).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (116).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (12).jpg (deflated 1%)
#   adding: temp/Validation/covid_n/img (125).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (129).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (141).jpeg (deflated 0%)
#   adding: temp/Validation/covid_n/img (142).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (157).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (160).jpeg (deflated 0%)
#   adding: temp/Validation/covid_n/img (165).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (168).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (17).jpeg (deflated 4%)
#   adding: temp/Validation/covid_n/img (175).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (178).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (183).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (186).jpeg (deflated 2%)
#   adding: temp/Validation/covid_n/img (191).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (196).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (20).jpg (deflated 1%)
#   adding: temp/Validation/covid_n/img (22).jpg (deflated 1%)
#   adding: temp/Validation/covid_n/img (26).jpeg (deflated 1%)
#   adding: temp/Validation/covid_n/img (29).jpeg (deflated 2%)
#   adding: temp/Validation/covid_n/img (33).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (1).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (1).png (deflated 0%)
#   adding: temp/Train/covid_p/img (10).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (10).png (deflated 0%)
#   adding: temp/Train/covid_p/img (100).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (101).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (102).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (103).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (105).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (106).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (108).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (109).jpg (deflated 12%)
#   adding: temp/Train/covid_p/img (110).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (111).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (112).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (113).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (114).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (115).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (116).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (117).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (12).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (12).png (deflated 1%)
#   adding: temp/Train/covid_p/img (120).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (121).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (122).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (13).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (14).jpg (deflated 6%)
#   adding: temp/Train/covid_p/img (15).png (deflated 0%)
#   adding: temp/Train/covid_p/img (16).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (17).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (17).png (deflated 1%)
#   adding: temp/Train/covid_p/img (19).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (19).png (deflated 1%)
#   adding: temp/Train/covid_p/img (2).png (deflated 0%)
#   adding: temp/Train/covid_p/img (20).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (21).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (21).png (deflated 2%)
#   adding: temp/Train/covid_p/img (23).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (24).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (24).png (deflated 1%)
#   adding: temp/Train/covid_p/img (25).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (25).png (deflated 1%)
#   adding: temp/Train/covid_p/img (26).png (deflated 1%)
#   adding: temp/Train/covid_p/img (28).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (28).png (deflated 0%)
#   adding: temp/Train/covid_p/img (29).jpg (deflated 7%)
#   adding: temp/Train/covid_p/img (3).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (30).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (31).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (33).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (34).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (35).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (37).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (39).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (4).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (4).png (deflated 2%)
#   adding: temp/Train/covid_p/img (41).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (42).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (43).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (44).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (45).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (46).jpg (deflated 11%)
#   adding: temp/Train/covid_p/img (49).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (5).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (50).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (52).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (53).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (55).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (56).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (57).jpg (deflated 6%)
#   adding: temp/Train/covid_p/img (59).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (6).png (deflated 2%)
#   adding: temp/Train/covid_p/img (60).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (61).jpg (deflated 11%)
#   adding: temp/Train/covid_p/img (62).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (63).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (66).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (67).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (69).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (7).png (deflated 3%)
#   adding: temp/Train/covid_p/img (71).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (72).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (73).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (74).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (75).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (78).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (79).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (8).jpg (deflated 6%)
#   adding: temp/Train/covid_p/img (8).png (deflated 2%)
#   adding: temp/Train/covid_p/img (80).jpg (deflated 10%)
#   adding: temp/Train/covid_p/img (81).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (83).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (84).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (85).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (87).jpg (deflated 4%)
#   adding: temp/Train/covid_p/img (88).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (89).jpg (deflated 5%)
#   adding: temp/Train/covid_p/img (9).jpg (deflated 3%)
#   adding: temp/Train/covid_p/img (90).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (92).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (94).jpg (deflated 2%)
#   adding: temp/Train/covid_p/img (95).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (96).jpg (deflated 0%)
#   adding: temp/Train/covid_p/img (97).jpg (deflated 1%)
#   adding: temp/Train/covid_p/img (99).jpg (deflated 0%)
#   adding: temp/Train/covid_n/img (27).jpg (deflated 2%)
#   adding: temp/Train/covid_n/img (270).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (271).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (28).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (35).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (36).jpeg (deflated 8%)
#   adding: temp/Train/covid_n/img (39).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (4).jpg (deflated 5%)
#   adding: temp/Train/covid_n/img (41).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (42).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (44).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (46).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (47).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (5).jpg (deflated 3%)
#   adding: temp/Train/covid_n/img (5).png (deflated 0%)
#   adding: temp/Train/covid_n/img (51).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (52).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (53).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (54).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (55).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (58).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (59).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (6).jpeg (deflated 0%)
#   adding: temp/Train/covid_n/img (6).jpg (deflated 5%)
#   adding: temp/Train/covid_n/img (60).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (62).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (63).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (65).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (66).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (67).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (68).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (7).jpg (deflated 4%)
#   adding: temp/Train/covid_n/img (70).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (73).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (74).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (75).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (76).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (79).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (8).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (80).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (82).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (83).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (85).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (86).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (87).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (88).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (89).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (9).jpg (deflated 5%)
#   adding: temp/Train/covid_n/img (90).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (92).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (93).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (95).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (97).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (98).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (1).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (1).png (deflated 2%)
#   adding: temp/Train/covid_n/img (1).jpg (deflated 2%)
#   adding: temp/Train/covid_n/img (10).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (100).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (101).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (104).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (105).jpeg (deflated 0%)
#   adding: temp/Train/covid_n/img (106).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (108).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (109).jpeg (deflated 5%)
#   adding: temp/Train/covid_n/img (11).jpg (deflated 1%)
#   adding: temp/Train/covid_n/img (111).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (113).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (114).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (117).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (119).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (12).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (120).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (121).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (122).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (124).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (127).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (128).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (130).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (133).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (134).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (136).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (137).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (138).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (14).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (14).jpg (deflated 1%)
#   adding: temp/Train/covid_n/img (143).jpeg (deflated 0%)
#   adding: temp/Train/covid_n/img (144).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (147).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (148).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (149).jpeg (deflated 0%)
#   adding: temp/Train/covid_n/img (15).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (150).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (153).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (154).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (155).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (156).jpeg (deflated 0%)
#   adding: temp/Train/covid_n/img (158).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (159).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (16).jpg (deflated 2%)
#   adding: temp/Train/covid_n/img (161).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (162).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (163).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (164).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (166).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (167).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (169).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (17).jpg (deflated 0%)
#   adding: temp/Train/covid_n/img (170).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (171).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (172).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (173).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (174).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (176).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (177).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (179).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (18).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (180).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (181).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (182).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (184).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (185).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (187).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (188).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (189).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (19).jpg (deflated 1%)
#   adding: temp/Train/covid_n/img (192).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (193).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (194).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (195).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (197).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (190).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (199).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (2).png (deflated 0%)
#   adding: temp/Train/covid_n/img (20).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (198).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (200).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (201).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (202).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (203).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (204).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (206).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (205).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (207).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (208).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (209).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (21).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (210).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (211).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (213).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (212).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (214).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (215).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (216).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (217).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (218).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (219).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (22).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (220).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (221).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (222).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (223).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (224).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (225).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (226).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (227).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (228).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (229).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (230).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (23).jpg (deflated 1%)
#   adding: temp/Train/covid_n/img (231).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (232).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (233).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (234).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (235).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (236).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (237).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (238).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (239).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (24).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (240).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (241).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (242).jpeg (deflated 0%)
#   adding: temp/Train/covid_n/img (243).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (244).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (246).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (245).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (247).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (248).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (249).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (25).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (25).jpg (deflated 2%)
#   adding: temp/Train/covid_n/img (250).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (252).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (253).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (254).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (255).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (256).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (251).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (257).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (258).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (259).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (260).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (261).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (262).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (263).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (264).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (265).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (266).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (267).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (268).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (269).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (29).jpg (deflated 1%)
#   adding: temp/Train/covid_n/img (3).jpeg (deflated 1%)
#   adding: temp/Train/covid_n/img (3).png (deflated 0%)
#   adding: temp/Train/covid_n/img (30).jpg (deflated 2%)
#   adding: temp/Train/covid_n/img (31).jpeg (deflated 3%)
#   adding: temp/Train/covid_n/img (31).jpg (deflated 4%)
#   adding: temp/Train/covid_n/img (32).jpeg (deflated 2%)
#   adding: temp/Train/covid_n/img (33).jpeg (deflated 1%)

# %%
#Finding the number of images for train test and validation
print("Number of images in traning covid p folder")
# !ls ./temp/Train/covid_p/ | wc -l
print("Number of images in traning covid_n folder")
# !ls ./temp/Train/covid_n/ | wc -l

print("Number of images in validation covid p folder")
# !ls ./temp/Validation/covid_p/ | wc -l
print("Number of images in validation covid_n folder")
# !ls ./temp/Validation/covid_n/ | wc -l

print("Number of images in test covid p folder")
# !ls ./temp/Test/covid_p/ | wc -l
print("Number of images in test covid_n folder")
# !ls ./temp/Test/covid_n/ | wc -l
# Out:
# Number of images in traning covid p folder
# 105
# Number of images in traning covid_n folder
# 220
# Number of images in validation covid p folder
# 15
# Number of images in validation covid_n folder
# 30
# Number of images in test covid p folder
# 30
# Number of images in test covid_n folder
# 60

# %%
import sklearn
import os 
import zipfile 
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras import layers 
from tensorflow.keras import Model 
import matplotlib.pyplot as plt

# %%
# local_zip = './Dataset/dataset.zip'
# zip_ref = zipfile.ZipFile(local_zip, 'r')
# zip_ref.extractall('./temp')
# zip_ref.close()

# %%
base_dir = './temp'
train_dir = os.path.join(base_dir, 'Train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cneg_dir = os.path.join(train_dir, 'covid_n')

# Directory with our training dog pictures
train_cpos_dir = os.path.join(train_dir, 'covid_p')

# Directory with our validation cat pictures
validation_cneg_dir = os.path.join(validation_dir, 'covid_n')

# Directory with our validation dog pictures
validation_pos_dir = os.path.join(validation_dir, 'covid_p')
